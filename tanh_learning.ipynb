# %% [markdown]
# <a href="https://colab.research.google.com/github/allaberdi001/Pythonic-AI/blob/main/tanh_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tanh
import numpy as np
import matplotlib.pyplot as plt

f=np.linspace(-10,10,50)
g=np.tanh(f)
plt.plot(f,g)
plt.xlabel("f")
plt.ylabel('g')
# Out:
# Text(0, 0.5, 'g')
